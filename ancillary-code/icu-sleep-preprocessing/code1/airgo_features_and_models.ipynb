# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os
import sys

sys.path.append('/home/wolfgang/repos/AirGo_Apnea_Detection')
from apnea_detection_functions import apply_apnea_prediction_models

sys.path.append('/home/wolfgang/repos/ICU-Sleep/code1')
from airgo_features import compute_airgo_features
from sleep_staging_functions import apply_airgo_sleep_staging_models

sys.path.append('/home/wolfgang/repos/sleep_research_io')
from sleep_research_functions import load_sleep_data, write_to_hdf5_file

# %matplotlib widget
import matplotlib.pyplot as plt

# %%
def filepaths_routine(data_dir, output_dir, verbose=True):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    files = os.listdir(data_dir)
    files.sort()

    filepaths_input = [os.path.join(data_dir, x) for x in files]
    filepaths_output = [os.path.join(output_dir, x) for x in files]
    
    if verbose:
        print(f'Number of files:         {len(filepaths_input)}')
        print(f'Sample filepath input:   {filepaths_input[0]}')
        print(f'Sample filepath output:  {filepaths_output[0]}')
              
    return filepaths_input, filepaths_output


def read_in_routine(filepath_input, fs_manual=10):

    datatype = filepath_input.split('.')[-1]

    assert datatype in ['csv', 'h5'], 'Currently, .csv or .h5 files are expected to be read in.'

    if datatype == 'csv':

        data = pd.read_csv(filepath_input)
        data.columns = [x.lower() for x in data.columns]
        data.datetime = pd.to_datetime(data.datetime, infer_datetime_format=1)
        data.set_index('datetime', inplace=True)
        data.rename({'band_smooth': 'movavg_0_5s'}, axis=1, inplace=True)
        hdr = {}
        
    if datatype == 'h5':
        
        data, hdr = load_sleep_data(filepath_input, idx_to_datetime=1)
        data[np.isinf(data)] = np.nan
        data = data.astype('float64')         
        fs = hdr['fs']
        data.columns = [x.lower() for x in data.columns]
        data.rename({'band_smooth': 'movavg_0_5s'}, axis=1, inplace=True)
        
        hdr['study_id'] = np.int32(hdr['study_id'])
        hdr['MRN'] = np.int32(hdr['MRN'])
        hdr['fs'] = np.int32(hdr['fs'])
        hdr['start_datetime'] = np.array([hdr['start_datetime'].year,hdr['start_datetime'].month,hdr['start_datetime'].day, hdr['start_datetime'].hour, hdr['start_datetime'].minute, hdr['start_datetime'].second, hdr['start_datetime'].microsecond])
        
        
    if ('band' in data) & (not 'band_unscaled' in data):
        print('Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled')
        data = renormalize_airgo(data)
    
    if 'fs' in hdr:
        fs = hdr['fs']
    else:
        fs = fs_manual
            
    return data, hdr, fs


def save_data_routine(data, filepath_output, hdr=None, overwrite=False):
    
    datatype = filepath_input.split('.')[-1]
    assert datatype in ['csv', 'h5'], 'Currently, .csv or .h5 expected.'
    
    dir_path = os.path.dirname(filepath_output)
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    
    if datatype == 'csv':
        data.to_csv(filepath_output)

    if datatype == 'h5':
        write_to_hdf5_file(data, filepath_output, hdr=hdr, overwrite=overwrite)

        
def airgo_resample_preprocess(data, seconds='0.1', interpolation_limit = 15):
    
    data = data.resample(f'{seconds}S').mean()
    data = data.interpolate(method='pchip', order=3, limit_area='inside', limit=interpolation_limit)
    return data

def clip_z_normalize(signal):

    signal_clipped = np.clip(signal.dropna(), np.percentile(signal.dropna(),1), np.percentile(signal.dropna(),99))
    mean = np.mean(signal_clipped.astype(np.float32))
    std = np.std(signal_clipped.astype(np.float32))
    signal = (signal - mean)/std

    return signal

def renormalize_airgo(data, fs=10):
    
    data['band_unscaled'] = data['band'].copy()
    data['band'] = clip_z_normalize(data.band)
    if 'movavg_0_5s' in data.columns:
        data.drop(['movavg_0_5s'], axis=1, inplace=True)
    data['movavg_0_5s'] = data['band'].reset_index()['band'].rolling(int(0.5*fs), center=True, min_periods=1).mean().values
    return data

# %% [markdown]
# ### Compute all airgo features (RR, MV, instability, complexity, actigraphy), apply apnea detection and sleep staging model. <br>  If other signals are available, like SpO2 (bedmaster, PSG), then models that use these signals will also be utilized.
# Currently models:
# Apnea Detection: Respiration Only (needs features computed), Respiration+SpO2.
# Sleep Staging: Based on Respiration Only, Actigraphy Only.

# %% [markdown]
# ### input:
# <b> list of paths to files. </b>
# files: either original airgo files, or merged with bedmaster or PSG data.

# %%
data_dir = './Data_Analysis/Airgo'
output_dir = './Data_Analysis/Airgo_Features'

data_dir = '/media/ssd2/icu_final_files'
output_dir = '/media/ssd2/icu_sleepstaging_TMP'

overwrite = True

filepaths_input, filepaths_output = filepaths_routine(data_dir, output_dir)
# Out:
# Number of files:         132
# Sample filepath input:   /media/ssd2/icu_final_files/icusleep_001.h5
# Sample filepath output:  /media/ssd2/icu_sleepstaging_TMP/icusleep_001.h5

# %% [markdown]
# ### Params / Settings

# %%
fs_manual = 10
do_resample_and_interpolation = False     # recommended for raw airgo, resampling to 'perfect 10Hz'
do_compute_airgo_features = False            # all features. by default, complexity features are computed in this code which are the slowest but needed for apnea prediction.
do_apply_apnea_prediction_models = False     # respiration-only and respiration+spo2 models.
do_apply_sleep_staging_models = True        # respiration-only, actigraphy-only.

# %%
# filepath_input = filepaths_input[0]
# filepath_output = filepaths_output[0]

for filepath_input, filepath_output in list(zip(filepaths_input, filepaths_output)):

    try:
#     if 1:
        
        if (os.path.exists(filepath_output)) & (not overwrite):
            print(f'{filepath_output} already exists. Continue.')
            continue

        print(filepath_input)

        data, hdr, fs = read_in_routine(filepath_input, fs_manual=fs_manual)

        # skip missing airgo:
        if not 'band' in data.columns:
            print('No AirGo data at all.')
            continue
            
        # skip missing airgo:
        if not 'band' in data.columns:
            print('No AirGo data at all.')
            continue        
        
        if data.acc_ai_10sec.dropna().mean() > 1:
            print(file_tmp)
            print('data.acc_ai_10sec.dropna().mean() > 1 --> V4.')
            continue
            
        if any(data.band_unscaled.dropna()>5000):
            print(file_tmp)
            print('unscaled airgo amplitude>5000 --> V4.')
            continue
                        
        
        if do_resample_and_interpolation:
            data = airgo_resample_preprocess(data)

        if do_compute_airgo_features:
            data = compute_airgo_features(data, fs=fs, complexity_features=1)

        if do_apply_apnea_prediction_models:
            data = apply_apnea_prediction_models(data, fs=fs)

        if do_apply_sleep_staging_models:
            
            data.drop(['stage_pred_amendsumeffort'], axis=1, inplace=True)
            data.drop(['stage_pred_activity1sec'], axis=1, inplace=True)
            data.drop(['stage_pred_vcomb1'], axis=1, inplace=True)
            
            data = apply_airgo_sleep_staging_models(data, fs=fs)

        save_data_routine(data, filepath_output, hdr=hdr, overwrite=overwrite)
        
    except Exception as e:
        print('Exception for ' + filepath_input)
        print(e)
        continue
# Out:
# /media/ssd2/icu_final_files/icusleep_001.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_001.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_003.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_003.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_004.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_004.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_006.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_006.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_007.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_007.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_011.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_011.h5
# "['stage_pred_activity1sec'] not found in axis"
# /media/ssd2/icu_final_files/icusleep_012.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_012.h5
# name 'file_tmp' is not defined
# /media/ssd2/icu_final_files/icusleep_013.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_013.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_014.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_014.h5
# name 'file_tmp' is not defined
# /media/ssd2/icu_final_files/icusleep_015.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_015.h5
# name 'file_tmp' is not defined
# /media/ssd2/icu_final_files/icusleep_018.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_018.h5
# "['stage_pred_activity1sec'] not found in axis"
# /media/ssd2/icu_final_files/icusleep_021.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_021.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_024.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_024.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_025.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_025.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_029.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_029.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_030.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_030.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_031.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /home/wolfgang/anaconda3/envs/AirGoSleep/lib/python3.6/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'mymodel.CHESTSleepNet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /media/ssd2/icu_final_files/icusleep_033.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_034.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_035.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_037.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_038.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# Exception for /media/ssd2/icu_final_files/icusleep_038.h5
# cannot do a non-empty take from an empty axes.
# /media/ssd2/icu_final_files/icusleep_039.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_042.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_045.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_046.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_047.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_048.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_049.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_050.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_051.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_052.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_054.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_056.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_061.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_063.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_064.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_067.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_068.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_069.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_071.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_072.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_074.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_076.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_077.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_078.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_079.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_080.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_081.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_082.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_083.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_084.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_085.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_086.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_087.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_088.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_089.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_090.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_091.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec
# /media/ssd2/icu_final_files/icusleep_092.h5
# Airgo signal not yet normalized. Do normalization on band and movavg_0_5s, keep original: band_unscaled
# amendsumeffort
# activity10sec

# %%
plt.subplots(sharex=True, figsize=(9,9))
ax1 = plt.subplot(611)
ax1.plot(data.band)
ax2 = plt.subplot(612, sharex=ax1)
ax2.plot(data.stage_pred_amendsumeffort_0)
ax3 = plt.subplot(613, sharex=ax1)
ax3.plot(data.stage_pred_amendsumeffort)
ax4 = plt.subplot(614, sharex=ax1)
ax4.plot(data.stage_pred_activity1sec)
ax5 = plt.subplot(615, sharex=ax1)
ax5.plot(data.stage_pred_activity10sec)
ax5 = plt.subplot(616, sharex=ax1)
ax5.plot(data.acc_ai_10sec)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# plt.subplots(3, sharex=True)
# ax1 = plt.subplot(511)
# ax1.plot(data.band)
# ax2 = plt.subplot(512, sharex=ax1)
# ax2.plot(data.apnea_prob_RO_a3.dropna())
# ax3 = plt.subplot(513, sharex=ax1)
# ax3.plot(data.stage_pred_amendsumeffort)
# ax4 = plt.subplot(514, sharex=ax1)
# ax4.plot(data.stage_pred_activity1sec)
# ax5 = plt.subplot(515, sharex=ax1)
# ax5.plot(data.acc_ai_1sec)

# %%
data.columns
# Out:
# Index(['accx', 'accy', 'accz', 'band', 'band_unscaled', 'movavg_0_5s',
#        'movavg_1_2s', 'movavg_1min', 'deriv1', 'ventilation0',
#        'ventilation_3s', 'ventilation_8s', 'ventilation_10s',
#        'ventilation_12s', 'ventilation_15s', 'ventilation_30s',
#        'ventilation_60s', 'ventilation_5min', 'ventilation_10min',
#        'ventilation_10s_smooth', 'hypo_10_60', 'movmedian_5min',
#        'movmedian_10min', 'movstd_8s', 'movstd_12s', 'movstd_15s',
#        'movstd_10s', 'movstd_30s', 'movstd_60s', 'movstd_5min', 'movstd_10min',
#        'katz_fd_10s_smoothed', 'katz_fd_30s_smoothed', 'katz_fd_45s_smoothed',
#        'katz_fd_60s_smoothed', 'sample_entropy_10s_smoothed',
#        'sample_entropy_30s_smoothed', 'sample_entropy_60s_smoothed',
#        'movavg_0_5s_unscaled', 'peaks', 'movstd_1min_unscaled',
#        'movstd_30sec_unscaled', 'rr_10s', 'rr_60s', 'rr_10s_smooth',
#        'movmedian_1min', 'movmedian_30sec', 'IBI', 'IBI_mean_5min',
#        'IBI_std_5min', 'ventilation_5min_deriv', 'troughs', 'inht', 'exht',
#        'inht_exht_ratio', 'inht_cycle_ratio', 'inht_exht_ratio_10sec',
#        'inht_cycle_ratio_10sec', 'TVpB', 'TVpB_regularity',
#        'TVpB_regularity_10sec', 'accx_1sec', 'accy_1sec', 'accz_1sec',
#        'acc_ai_1sec', 'acc_ai_10sec', 'acc_enmo', 'acc_enmo_1sec',
#        'acc_enmo_10sec', 'position_cluster', 'ventilation_cvar_30sec',
#        'IBI_cvar_30sec', 'instability_index_30sec', 'ventilation_cvar_1min',
#        'IBI_cvar_1min', 'instability_index_1min', 'ventilation_cvar_2min',
#        'IBI_cvar_2min', 'instability_index_2min', 'ventilation_cvar_5min',
#        'IBI_cvar_5min', 'instability_index_5min'],
#       dtype='object')
