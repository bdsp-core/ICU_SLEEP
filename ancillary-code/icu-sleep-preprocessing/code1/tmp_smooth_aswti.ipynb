# %%
import os
import sys
import pandas as pd
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from sleep_analysis_functions import sleep_stage_aswti
sys.path.append('C:/Users/wg984/Wolfgang/repos/sleep_research_io')
sys.path.append('/home/wolfgang/repos/sleep_research_io')

from sleep_research_functions import *

# %%
fs = 10

sleep_stage = np.concatenate([np.ones(fs*60*100) * np.nan,
                              np.ones(fs*60*10) * 3, 
                             np.ones(fs*60*25) * 4, 
                             np.ones(fs*60*20) * 2, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*5) * 3, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*5) * 3, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*5) * 3, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*15) * np.nan, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*5) * 3, 
                             np.ones(fs*60*5) * 5, 
                             np.ones(fs*60*30) * 2, 
                             np.ones(fs*60*40) * 1, 
                             np.ones(fs*60*30) * 5, 
                             np.ones(fs*60*40) * 2, 
                             np.ones(fs*60*40) * 5,
                             np.ones(fs*60*100) * np.nan])

data = pd.DataFrame()
data['sleep_stage'] = sleep_stage
data.index = pd.date_range(start='2020-04-01 20:00:00', periods = len(sleep_stage), freq='100ms')

# %%
data = sleep_stage_aswti(data, 'sleep_stage', min_sleep=30, fs=10)

# %%
plt.figure(figsize=(6,2))
plt.plot(data.sleep_stage+0.075, c='blue')
# plt.plot(data.sleep_stage_aswti1+0.1, c='orange')
plt.plot(data.sleep_stage_aswti, c='red')

plt.yticks([1, 2, 3, 4, 5], labels = ['N3', 'N2', 'N1', 'R', 'W'])
# plt.yticks_labels()
# plt.plot(data.aswti_to_replace_and_wake, c='green')
# plt.plot(data.sleep_binary)
# plt.plot(data.sleep_30min_present, c='gray')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /home/wolfgang/anaconda3/envs/AirGoSleep/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ([<matplotlib.axis.YTick at 0x7fe579e54358>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
dir_input = f'//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/Sleep_And_Breathing/icu_files_step4'
file = os.listdir(dir_input)[19]

# %%
data, hdr, fs = read_in_routine(os.path.join(dir_input, file))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-14f19f5cfc30> in <module>
# ----> 1 data, hdr, fs = read_in_routine(os.path.join(dir_input, file))
#
# C:/Users/wg984/Wolfgang/repos/sleep_research_io\sleep_research_functions.py in read_in_routine(filepath_input, fs_manual, check_airgo_scaling)
#     285     if datatype == 'h5':
#     286
# --> 287         data, hdr = load_sleep_data(filepath_input, idx_to_datetime=1)
#     288         fs = hdr['fs']
#     289         data.columns = [x.lower() for x in data.columns]
#
# C:/Users/wg984/Wolfgang/repos/sleep_research_io\sleep_research_functions.py in load_sleep_data(filepath, load_all_signals, idx_to_datetime, signals_to_load, load_events, verbose)
#     170             if not signal_to_load_tmp in ff.keys():
#     171                 continue
# ...

# %%
[x for x in data.columns if 'stage' in x]
