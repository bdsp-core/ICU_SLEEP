# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/media/mad3/Projects/ICU_SLEEP_STUDY/data/data_analysis/Study/research_daynight_categories.csv')

# %%
df = df[np.isin(df.category,['A','B'])]
df.to_csv('categorization_w_airgo.csv', index=False)

# %%
df.iloc[21:]
# Out:
#     night_id category
# 78   015_n06        A
# 80   018_n02        A
# 81   018_n03        A
# 84   021_n02        A
# 85   021_n03        A
# ..       ...      ...
# 787  188_n02        A
# 788  188_n03        A
# 789  188_n04        A
# 799  189_n10        A
# 800  189_n11        A
#
# [279 rows x 2 columns]

# %%
icu_micro_list = pd.DataFrame()
icu_micro_list['night_id'] = [
    '015_n04',
    '015_n06',
    '018_n02',
    '018_n03',
    '021_n02',
    '021_n03',
    '024_n02',
    '025_n04',
    '079_n04',
    '079_n05',
    '081_n04',
    '082_n01',
    '083_n02',
    '083_n03',
    '084_n03',
    '084_n03',
    '084_n05',
    '086_n02',
    '087_n04',
    '088_n02'
]

# %%
icu_micro_list['study_id'] = icu_micro_list['night_id'].apply(lambda x: x.split('_')[0])

# %%
icu_micro_list.to_csv('icu_micro_list.csv', index=False)

# %%
icu_micro_list.shape
# Out:
# (20, 2)
