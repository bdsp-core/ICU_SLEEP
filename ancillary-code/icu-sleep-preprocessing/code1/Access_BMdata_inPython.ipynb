# %%
import time
import h5py
import scipy.io as sio
import numpy as np
import pandas as pd

# %%
UpperDir = '//mad3/PHS-RISC-LM4/ConvertedData/bedmaster/final/2018/'
months = ['8','9','10','11','12']

month = months[0]

# %%
bm_file = UpperDir + month + '/' + 'BIG06_620-1533123039_0_fixed.mat'

# %%
with h5py.File(bm_file) as ff:

    wv_signals = list(ff['wv'].keys())
    vs_signals = list(ff['vs'].keys())
    samplesignal = ff['vs'][vs_signals[0]][:]
    print(ff['vs_time'][vs_signals[0]])
    print(ff['vs_time'][vs_signals[0]][:])
# Out:
# <HDF5 dataset "APNEA": shape (8751, 1), type "<f8">
# [[737273.31297454]
#  [737273.31299769]
#  [737273.31302083]
#  ...
#  [737273.51547454]
#  [737273.51549769]
#  [737273.51552083]]

# %%
wv_signals
# Out:
# ['I', 'II', 'III', 'RR', 'SPO2', 'V']

# %%
print(vs_signals)
# Out:
# ['APNEA', 'CUFF', 'HR', 'NBPD', 'NBPM', 'NBPS', 'PVC', 'RESP', 'SPO2%', 'SPO2R', 'STAVF', 'STAVL', 'STAVR', 'STI', 'STII', 'STIII', 'STV', 'STV1', 'STV2', 'STV3', 'STV4', 'STV5', 'STV6']

# %%
samplesignal
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])
