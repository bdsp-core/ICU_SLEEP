# %%
import pandas as pd
import os

# %%
# we need info for multiple patient recordings for split:
airgo_masterlist = pd.read_csv('C:/Users/wg984/Dropbox (Partners HealthCare)/AirGoSleepLabData/MasterList_Main_1.23.20.csv')
airgo_masterlist = airgo_masterlist[airgo_masterlist.IncludedInStudy==1]

# %%
airgo_masterlist.columns
# Out:
# Index(['IncludedInStudy', 'ExclusionReason', 'SID', 'SID_PreAdjustment',
#        'AppleID', 'Date', 'Patient's Last Name', 'Patient's First Name',
#        'Gender', 'Race', 'Ethnicity', 'Room #', 'Insurance', 'Test Type',
#        'Visit #', 'Unit #', 'Tech', 'Referring MD', 'STAT/Int'l/comments',
#        'Scorer', 'Date/Out', 'Date In', 'Days Out', 'MD', 'MD Comments',
#        'Sensors', 'Notes (and exclusion)', 'Unnamed: 24', 'FurtherNotes',
#        'MRN', 'Path', 'Unnamed: 31'],
#       dtype='object')

# %%
paths = airgo_masterlist['Path']

# %%
edffilenames = []
for path in paths:
    files = os.listdir(path)
    edffile = [x for x in files if '.edf' in x]
    edffilenames.append(edffile[0])

# %%
paths = paths + '\\' + edffilenames

# %%
len(edffilenames)
# Out:
# 412

# %%
len(paths)
# Out:
# 412

# %%
paths.to_csv('edfs_for_deidentification_airgostudy.csv', index=False)
# Out:
# C:\Users\wg984\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
files_deidentified=os.listdir('//mad3/MGH-NEURO-CDAC/Projects/Deidentified_edf_for_wolfgang')

# %%
set(edffilenames) - set(files_deidentified)
# Out:
# {'Hodges~ Benjam_21dc8838-1773-4d20-b2f5-71fee3df57ca.edf'}
