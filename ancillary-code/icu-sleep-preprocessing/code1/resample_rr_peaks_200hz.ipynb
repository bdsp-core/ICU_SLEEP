# %%
import pandas as pd
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from scipy.signal import resample, resample_poly

# %%
fs_1 = 240

rr_peaks_1 = np.zeros((fs_1*30, 1))
rr_peaks_1[::fs_1] = 1

# %%
fs_2 = 200

rr_peaks_2 = resample(rr_peaks_1,  int(rr_peaks_1.shape[0]/240*200))

# %%
plt.figure()
plt.plot(rr_peaks_1)
plt.plot(rr_peaks_2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
