# %%
import pandas as pd
import numpy as np
import os
import datetime
import matplotlib.pyplot as plt

# %%
airgo_research_dir = '//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/data_analysis/AirGo/airgo_research'
savedir = '//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/data_analysis/AirGo/airgo_research_4Hz'

# %%
files = os.listdir(airgo_research_dir)
files[34]
# Out:
# 'airgo_043.csv'

# %%
for file in files:
    fs10_data = pd.read_csv(os.path.join(airgo_research_dir, file))
    fs10_data['DateTime'] = pd.to_datetime(fs10_data['DateTime'], infer_datetime_format=1)
    fs10_data.set_index('DateTime', inplace=True)
    fs4_data = fs10_data.resample(datetime.timedelta(seconds=0.25)).mean()
    fs4_data.to_csv(os.path.join(savedir, file.split('.csv')[0] + '_4Hz.csv'))
    
    if 0:
        plt.figure()
        plt.plot(fs10_data.index[:100], fs10_data['Band'][:100])
        plt.plot(fs4_data.index[:40] + datetime.timedelta(seconds=0.125), fs2_data['Band'][:40])
        plt.legend(['fs10','fs4'])
        plt.show()
# Out:
# C:\Users\wg984\.conda\envs\visualization\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fs2_data.shape[0]*2.5

# %%
fs10_data.shape

# %%
# fs10_data.head()
# Out:
#                          accX  accY  accZ    Band  CRCStatus
# DateTime
# 2019-03-14 17:49:25.670 -3.69 -1.79 -8.41  2421.0        NaN
# 2019-03-14 17:49:25.770 -3.65 -1.86 -8.60  2417.0        NaN
# 2019-03-14 17:49:25.870 -3.63 -1.90 -8.60  2413.0        NaN
# 2019-03-14 17:49:25.970 -3.67 -1.91 -8.62  2410.0        NaN
# 2019-03-14 17:49:26.070 -3.62 -1.83 -8.60  2411.0        NaN
