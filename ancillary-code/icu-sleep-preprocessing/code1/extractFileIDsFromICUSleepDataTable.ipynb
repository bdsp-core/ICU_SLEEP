# %%
import numpy as np
import pandas as pd
import os

# %%
LogDir = '//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/data_analysis/Study/'

# %%
table = pd.read_csv( os.path.join(LogDir,'ICUSleep_DataTable_ICU.csv'))

# %%
fileIDs = np.unique(table.BMFileID.dropna())

# %%
fileIDs.shape
# Out:
# (150,)

# %%
fileIDs[:5]
# Out:
# array(['BLK07_754-1529299617', 'BLK07_754-1556937509',
#        'BLK07_756-1554043989', 'BLK07_756-1555462981',
#        'BLK07_756-1560316718'], dtype=object)

# %%
pd.DataFrame(fileIDs).to_csv(os.path.join(LogDir,'allFileIDsFromICUSleep_DataTable.csv'), index=False, header=False)
