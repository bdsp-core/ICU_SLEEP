# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/data_analysis/AirGo/airgo_research/airgo_005.csv')

# %%
data
# Out:
#         Unnamed: 0                 DateTime   Band  accX  accY  accZ  \
# 0                1  2018-06-19 20:49:53.200  65528   254   249    13
# 1                2  2018-06-19 20:49:53.300  65528   253   249    13
# 2                3  2018-06-19 20:49:53.400  65528   252   250    13
# 3                4  2018-06-19 20:49:53.500  65528   254   249    13
# 4                5  2018-06-19 20:49:53.600  65528   253   249    14
# ...            ...                      ...    ...   ...   ...   ...
# 795507      354114  2018-06-20 18:54:34.500  65528   246     7    11
# 795508      354115  2018-06-20 18:54:34.600  65528   245     8    10
# 795509      354116  2018-06-20 18:54:34.700  65528   246     8    10
# 795510      354117  2018-06-20 18:54:34.800  65528   246     8     9
# 795511      354118  2018-06-20 18:54:34.900  65528   246     7     9
#
#         CRCStatus
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# ...

# %%
data['DateTime'] = pd.to_datetime(data['DateTime'], infer_datetime_format=1)

# %%
data['DateTime'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 795507    False
# 795508    False
# 795509    False
# 795510    False
# 795511    False
# Name: DateTime, Length: 795512, dtype: bool

# %%
dupl = data.loc[data['DateTime'].duplicated(),:].Band

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dupl)

# %%
plt.plot(data.Band)

# %%
data = '//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/enrolled_subjects/005_Goodall/AirGo/005_2018_06_20am_airgo raw AirGo 78a5043e94f3 2018-06-20 090423_Raw.csv'

# %%
data = pd.read_csv(data)

# %%
data.columns
# Out:
# Index(['logId', ' sampleNumber', ' rawBeltValue', ' accX', ' accY', ' accZ'], dtype='object')

# %%
np.unique(data[' rawBeltValue'])
# Out:
# array([65528], dtype=int64)

# %%
plt.plot(data[' accX'])
