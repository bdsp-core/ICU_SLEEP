# %% [markdown]
# ## pipeline that processes all converted bedmaster data.
# all steps are set up so that they are not executed if corresponding output does already exist in output folder. therefore, if new bedmaster data comes in, just run this pipeline. data already there (older patients) does not get run again, while new patients get processed.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("C:/Users/wg984/Wolfgang/repos/Bedmaster-ICU-tools/code/")
sys.path.append("C:/Users/wg984/Wolfgang/repos/Bedmaster-ICU-tools/user_files/")
from bmresearch_tools import BMR_load, BMR_plot, get_metadata
from bmfileID_h5_to_studyID_h5 import bmfileID_to_studyID
from format_multiple_bedmaster_files import format_multiple_bedmaster_files
from bedmaster_resample_waveforms import bedmaster_resample_waveforms
import matlab.engine
eng = matlab.engine.start_matlab()

# %% [markdown]
# + ### step 1. format bedmaster converted to bedmaster research:
#  - input: a directory with files that need to be formatted.
#  - output: each bedmaster fileID gets formatted. output with same fileID name .h5 (data_analysis/BMR_fileID/fileID.h5)

# %%
format_multiple_bedmaster_files()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-127b0b03c170> in <module>
# ----> 1 format_multiple_bedmaster_files()
#
# NameError: name 'format_multiple_bedmaster_files' is not defined

# %%
df = pd.DataFrame([[2,2],[3,3],[4,5]])
df.drop([4],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2cdd2adff9f1> in <module>
#       1 df = pd.DataFrame([[2,2],[3,3],[4,5]])
# ----> 2 df.drop([4],axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: '[4] not found in axis'

# %% [markdown]
# + ### step 2. merge all bedmaster files for a patient, save the file as BMR_patientID.h5
#  - input: formatted files from step1
#  - output: BMR files for each subject (data_analysis/BMR_studyID/BMR_studyID.h5)

# %%
study_ids_to_process = [1,2,3]

# %%
bmfileID_to_studyID()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-82c533bade32> in <module>
# ----> 1 bmfileID_h5_to_studyID_h5()
#
# NameError: name 'bmfileID_h5_to_studyID_h5' is not defined

# %% [markdown]
# + ### step 3. resample waveforms (including ecg)
#  - input: output from step2, i.e. BMR files for a patient
#  - EKG gets resampled to 240Hz and gets saved in an .h5 with a slightly different format: signal array for each lead and startdatetime.
#  - output: BMR_resampled_ECG/ECG_studyID.h5

# %%
bedmaster_resample_waveforms()

# %% [markdown]
# + ### step 4. HRV analysis.
#  - input: resampled (evenly spaced, 240 Hz) ECG from step3
#  - detects R peaks and runs HRV analysis
#  - output: HRV_analysis/studyID_... .csv

# %%
study_id = str(int(1)).zfill(3)
force_overwrite = 0
eng.HRV_Analysis_ICUSleepProject(study_id, force_overwrite, nargout=0)
# Out:
# ---------------------------------------------------------------------------
# MatlabExecutionError                      Traceback (most recent call last)
# <ipython-input-25-9f80ea1b1161> in <module>
#       1 study_id = str(int(1)).zfill(3)
#       2 force_overwrite = 0
# ----> 3 eng.HRV_Analysis_ICUSleepProject(study_id, force_overwrite, nargout=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matlab\engine\matlabengine.py in __call__(self, *args, **kwargs)
#      69         else:
#      70             return FutureResult(self._engine(), future, nargs, _stdout,
# ---> 71                                 _stderr, feval=True).result()
#      72
#      73     def __validate_engine(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matlab\engine\futureresult.py in result(self, timeout)
#      65                 raise TypeError(pythonengine.getMessage('TimeoutCannotBeNegative'))
#      66
# ---> 67         return self.__future.result(timeout)
#      68
#      69     def cancel(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matlab\engine\fevalfuture.py in result(self, timeout)
#      80                 raise TimeoutError(pythonengine.getMessage('MatlabFunctionTimeout'))
#      81
# ---> 82             self._result = pythonengine.getFEvalResult(self._future,self._nargout, None, out=self._out, err=self._err)
#      83             self._retrieved = True
#      84             return self._result
#
# MatlabExecutionError:
#   File C:\Program Files\MATLAB\R2018b\toolbox\matlab\imagesci\h5read.m, line 66, in h5read
#
#   File C:\Users\wg984\Wolfgang\repos\ICU-Sleep\code1\Cardiovascular_Toolbox\HRV_Analysis_ICUSleepProject.m, line 37, in HRV_Analysis_ICUSleepProject
# The filename specified was either not found on the MATLAB path or it contains unsupported characters.

# %%
eng.quit()

# %% [markdown]
# + ### step 5. NN to DateTime
#  - input: NN as computed in step2.
