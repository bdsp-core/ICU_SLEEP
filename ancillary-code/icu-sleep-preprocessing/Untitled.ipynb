# %%
import plotly.graph_objects as go
import plotly.io as pio

# %%
import sys
sys.path.append("C:/Users/wg984/Wolfgang/repos/Bedmaster-ICU-tools/code/")
from bmresearch_tools import BMR_load, BMR_plot, get_metadata

# %%
signal_I = BMR_load('//mad3/MGH-NEURO-CDAC/Projects/ICU_SLEEP_STUDY/data/data_analysis/BMR_studyID/BMR_001.h5', signals = ['I'],compute_datetime=0, loadEvents=0)

# %%
signal_I['I'].shape[0]/240/3600/24
# Out:
# 12.55919675925926

# %%
signal_I['I'].columns
# Out:
# Index(['signal', 'posix'], dtype='object')

# %%
fig = go.FigureWidget()
fig.add_scatter(y=[2, 4, 3, 2.5])
fig
# Out:
# FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '3fa41893-ce6e-4abf-b3a2-96f421916319', 'y': [2, 4, 3, …

# %%
pio.write_json(fig, 'scatter.plotly')

# %%
fig = pio.read_json('scatter.plotly', output_type='FigureWidget')
fig
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'type': 'scatter',
#               'uid': '9…

# %%
fig_styled = pio.read_json('scatter-styled.plotly', output_type='FigureWidget')
fig_styled
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'type': 'scatter',
#               'uid': 'a…

# %%
fig.layout
# Out:
# Layout({
#     'autosize': True,
#     'shapes': [{'fillcolor': 'rgb(255, 0, 0)',
#                 'line': {'color': 'rgb(255, 0, 0)'},
#                 'opacity': 0.3,
#                 'x0': 0.5947885762757561,
#                 'x1': 0.8630582893012718,
#                 'y0': 3.931746250947656,
#                 'y1': 3.962944904924427}],
#     'template': '...',
#     'xaxis': {'autorange': False, 'range': [0.423367135100607, 1.4422109549664646]},
#     'yaxis': {'autorange': False, 'range': [3.663091175036568, 4.06289614822038], 'type': 'linear'}
# })

# %%
fig_styled.layout
# Out:
# Layout({
#     'annotations': [{'ax': -216,
#                      'ay': -187,
#                      'showarrow': False,
#                      'text': 'apnea',
#                      'x': 0.7013216753111594,
#                      'y': 3.974499961952861}],
#     'autosize': True,
#     'shapes': [{'fillcolor': 'rgb(255, 0, 0)',
#                 'line': {'color': 'rgb(255, 0, 0)'},
#                 'opacity': 0.3,
#                 'x0': 0.583166783653712,
#                 'x1': 0.8514364966792278,
#                 'y0': 3.9242354638791737,
#                 'y1': 3.9554341178559453},
#                {'fillcolor': 'rgb(255, 0, 0)',
#                 'line': {'color': '#444444'},
#                 'opacity': 0.3,
#                 'x0': 1.1313280023267875,
#                 'x1': 1.2572307557322642,
#                 'y0': 3.9340572623533427,
#                 'y1': 3.948501083638885}],
#     'template': '...',
# ...

# %%
with open('scatter-styled.plotly', 'r') as f:
    json_str = f.read()

# %%
json_str;

# %%
fig = pio.read_json('scatter.plotly', output_type='FigureWidget')

# %%
fig.layout
# Out:
# Layout({
#     'autosize': True,
#     'shapes': [{'fillcolor': 'rgb(255, 0, 0)',
#                 'line': {'color': 'rgb(255, 0, 0)'},
#                 'opacity': 0.42,
#                 'x0': -0.004311721494730101,
#                 'x1': 2.20584477802619,
#                 'y0': 2.993499106127093,
#                 'y1': 3.2437835202340324},
#                {'fillcolor': '#7f7f7f', 'line': {'color': '#444444'}, 'opacity': 0.3}],
#     'template': '...',
#     'xaxis': {'autorange': True, 'range': [-0.17997444905780902, 3.1799744490578092]},
#     'yaxis': {'autorange': True, 'range': [1.8753453599869983, 4.124654640013002], 'type': 'linear'}
# })

# %%
fig
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'type': 'scatter',
#               'uid': 'd…

# %%
fig_styled = pio.read_json('scatter-styled.plotly', output_type='FigureWidget')

# %%
fig_styled.layout
# Out:
# Layout({
#     'autosize': True,
#     'shapes': [{'fillcolor': 'rgb(255, 0, 0)',
#                 'line': {'color': 'rgb(255, 0, 0)'},
#                 'opacity': 0.42,
#                 'x0': -0.004311721494730101,
#                 'x1': 2.20584477802619,
#                 'y0': 2.993499106127093,
#                 'y1': 3.2437835202340324}],
#     'template': '...',
#     'xaxis': {'autorange': True},
#     'yaxis': {'autorange': True, 'type': 'linear'}
# })

# %%
fig_styled
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'type': 'scatter',
#               'uid': 'e…
